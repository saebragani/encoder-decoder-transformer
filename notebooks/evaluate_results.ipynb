# %%
import torch
import torch.nn as nn

import warnings
warnings.filterwarnings("ignore")

# %%
import sys
from pathlib import Path
project_root = str(Path('.').resolve().parent)
if project_root not in sys.path:
    sys.path.append(project_root)

# %%
from train import prepare_model_data

# %%
from config import ConfigLoader

# %%
from dotenv import load_dotenv
import os

# %%
config = ConfigLoader.from_yaml("../config/parameters.yaml")

# %%
load_dotenv(dotenv_path="../.env", override=True)
hf_token = os.getenv("HF_TOKEN")

# %%
model, train_data_loader, val_data_loader, trained_tokens_dict = prepare_model_data(
    config=config,
    hf_token=hf_token
)
# Out:
# Filtered dataset: 997,064 / 1,000,000 pairs kept (99.7%)

# %%
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
device
# Out:
# device(type='cpu')

# %%
state = torch.load(
    f="../outputs/model_weights/model__epoch_19.pt",
    map_location=device,
)

# %%
model.load_state_dict(state["model_state_dict"])
# Out:
# <All keys matched successfully>

# %%
model.eval()
# Out:
# TransformerBlock(
#   (source_token_embedding): TokenEmbedding(
#     (token_embedding): Embedding(30000, 512)
#   )
#   (source_psition_encoding): PsitionEncoding(
#     (dropout): Dropout(p=0.1, inplace=False)
#   )
#   (target_token_embedding): TokenEmbedding(
#     (token_embedding): Embedding(30000, 512)
#   )
#   (target_psition_encoding): PsitionEncoding(
#     (dropout): Dropout(p=0.1, inplace=False)
#   )
#   (encoder_module_list): ModuleList(
#     (0-5): 6 x EncoderBlock(
#       (multi_head_attention): MultiHeadAttention(
#         (w_q): Linear(in_features=512, out_features=512, bias=False)
#         (w_k): Linear(in_features=512, out_features=512, bias=False)
#         (w_v): Linear(in_features=512, out_features=512, bias=False)
#         (w_o): Linear(in_features=512, out_features=512, bias=False)
#         (dropout): Dropout(p=0.1, inplace=False)
#       )
#       (feed_forward): FeedForward(
#         (l1): Linear(in_features=512, out_features=2048, bias=True)
# ...
